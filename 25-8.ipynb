# %% [markdown]
# For example:
#
# ```
# 162,817,812
# 57,618,57
# 906,360,560
# 592,479,940
# 352,342,300
# 466,668,158
# 542,29,236
# 431,825,988
# 739,650,466
# 52,470,668
# 216,146,977
# 819,987,18
# 117,168,530
# 805,96,715
# 346,949,466
# 970,615,88
# 941,993,340
# 862,61,35
# 984,92,344
# 425,690,689
# ```
#
# This list describes the position of 20 junction boxes, one per line. Each position is given as X,Y,Z coordinates. So, the first junction box in the list is at X=162, Y=817, Z=812.
#
# To save on string lights, the Elves would like to focus on connecting pairs of junction boxes that are as close together as possible according to straight-line distance. In this example, the two junction boxes which are closest together are 162,817,812 and 425,690,689.
#
# By connecting these two junction boxes together, because electricity can flow between them, they become part of the same circuit. After connecting them, there is a single circuit which contains two junction boxes, and the remaining 18 junction boxes remain in their own individual circuits.
#
# Now, the two junction boxes which are closest together but aren't already directly connected are 162,817,812 and 431,825,988. After connecting them, since 162,817,812 is already connected to another junction box, there is now a single circuit which contains three junction boxes and an additional 17 circuits which contain one junction box each.
#
# The next two junction boxes to connect are 906,360,560 and 805,96,715. After connecting them, there is a circuit containing 3 junction boxes, a circuit containing 2 junction boxes, and 15 circuits which contain one junction box each.
#
# The next two junction boxes are 431,825,988 and 425,690,689. Because these two junction boxes were already in the same circuit, nothing happens!
#
# This process continues for a while, and the Elves are concerned that they don't have enough extension cables for all these circuits. They would like to know how big the circuits will be.
#
# After making the ten shortest connections, there are 11 circuits: one circuit which contains 5 junction boxes, one circuit which contains 4 junction boxes, two circuits which contain 2 junction boxes each, and seven circuits which each contain a single junction box. Multiplying together the sizes of the three largest circuits (5, 4, and one of the circuits of size 2) produces 40.

# %%
data_test = """162,817,812
57,618,57
906,360,560
592,479,940
352,342,300
466,668,158
542,29,236
431,825,988
739,650,466
52,470,668
216,146,977
819,987,18
117,168,530
805,96,715
346,949,466
970,615,88
941,993,340
862,61,35
984,92,344
425,690,689"""

# %% [markdown]
# ## Part 1

# %%
import numpy as np
from itertools import combinations
from tqdm import tqdm

np.set_printoptions(linewidth=110)
def data_to_3d(data):
    return np.array([list(map(int, line.split(","))) for line in data.splitlines()])
def calc_distances(pos):
    dist = []
    for i1, i2 in tqdm(list(combinations(range(len(pos)), 2))):
        dist.append(
            ( i1, i2, np.linalg.norm(pos[i1] - pos[i2]) )
        )
    return dist

# %%
def mk_circuits(pos, dist, n_connect = 10):
    circuits = []
    j2circ = {}
    for i in range(n_connect):
        j1, j2 = tuple(pos[dist[i][0]]), tuple(pos[dist[i][1]])
        # print(j1, j2)
        if not j1 in j2circ and not j2 in j2circ:
            circuits.append([j1, j2])
            circidx = len(circuits)-1
            print(f"joining in new circuit #{circidx}: {j1} {j2}")
            j2circ[j1] = circidx
            j2circ[j2] = circidx
        elif j1 in j2circ and not j2 in j2circ:
            circidx = j2circ[j1]
            print(f"joining pre-existing circuit #{circidx}: {j2}")
            circuits[circidx].append(j2)
            j2circ[j2] = circidx
        elif not j1 in j2circ and j2 in j2circ:
            circidx = j2circ[j2]
            print(f"joining pre-existing circuit #{circidx}: {j1}")
            circuits[circidx].append(j1)
            j2circ[j1] = circidx
        elif j1 in j2circ and j2 in j2circ:
            if j2circ[j1] == j2circ[j2]:
                print(f"skip. elements {j1} and {j2} already part of circuit {j2circ[j1]}")
                continue
            # everybody joins circuit1
            print(f"joining circuits {j2circ[j1]} (n={len(circuits[j2circ[j1]])}) and {j2circ[j2]} (n={len(circuits[j2circ[j2]])}) in {j2circ[j1]}")
            circid_j2 = j2circ[j2]
            circuits[j2circ[j1]].extend(circuits[circid_j2])
            for j in circuits[circid_j2]:
                j2circ[j] = j2circ[j1]
            circuits[circid_j2] = [] 
            print(f"new len of circuit {j2circ[j1]} (n={len(circuits[j2circ[j1]])})")

        else:
            assert False
    # return circuits
    return (
        circuits + 
        [[tuple(p)] for p in pos if not tuple(p) in j2circ]
    )

# %%
from functools import reduce

pos = data_to_3d(data_test)
dist = calc_distances(pos)
dist = sorted(dist, key = lambda x: x[2])
circuits = mk_circuits(pos, dist, n_connect = 10)
reduce(lambda x,y: x *y, sorted([len(c) for c in circuits], reverse=True)[:3])
# Out:
# 100%|████████████████████████████████████████████████| 190/190 [00:00<00:00, 79899.51it/s]
# joining in new circuit #0: (162, 817, 812) (425, 690, 689)
# joining pre-existing circuit #0: (431, 825, 988)
# joining in new circuit #1: (906, 360, 560) (805, 96, 715)
# skip. elements (431, 825, 988) and (425, 690, 689) already part of circuit 0
# joining in new circuit #2: (862, 61, 35) (984, 92, 344)
# joining in new circuit #3: (52, 470, 668) (117, 168, 530)
# joining in new circuit #4: (819, 987, 18) (941, 993, 340)
# joining pre-existing circuit #1: (739, 650, 466)
# joining pre-existing circuit #0: (346, 949, 466)
# joining circuits 1 (n=3) and 2 (n=2) in 1
# new len of circuit 1 (n=5)
# 40

# %%
from aocd import get_data
data = get_data(day=8, year=2025)
len(data.splitlines())
# Out:
# 1000

# %%
from functools import reduce

pos = data_to_3d(data)
dist = calc_distances(pos)
dist = sorted(dist, key = lambda x: x[2])
circuits = mk_circuits(pos, dist, n_connect = 1000)
reduce(lambda x,y: x *y, sorted([len(c) for c in circuits], reverse=True)[:3])
# Out:
# 100%|█████████████████████████████████████████| 499500/499500 [00:00<00:00, 534642.48it/s]
# joining in new circuit #0: (22662, 6955, 7124) (22772, 6437, 7418)
# joining in new circuit #1: (920, 52747, 91976) (770, 52177, 91358)
# joining in new circuit #2: (42553, 71880, 29425) (43033, 72228, 28791)
# joining in new circuit #3: (15380, 19660, 32704) (14656, 18849, 33244)
# joining in new circuit #4: (37906, 65907, 6058) (37722, 67135, 5895)
# joining in new circuit #5: (81678, 82926, 23052) (82215, 83791, 22210)
# joining in new circuit #6: (2063, 92337, 39347) (3334, 92501, 40239)
# joining in new circuit #7: (63502, 18502, 70887) (64925, 17822, 70885)
# joining in new circuit #8: (45307, 39806, 4155) (46489, 40376, 2913)
# joining in new circuit #9: (92384, 71229, 4904) (93976, 70443, 5258)
# joining in new circuit #10: (66381, 11590, 38596) (64584, 11393, 39148)
# joining in new circuit #11: (10466, 12639, 4121) (9446, 12943, 2526)
# joining in new circuit #12: (96149, 7722, 78223) (94776, 6539, 78851)
# joining in new circuit #13: (97992, 22128, 48571) (99950, 22091, 48206)
# joining in new circuit #14: (45135, 53096, 88481) (46881, 53171, 87491)
# joining in new circuit #15: (56071, 93540, 16298) (57450, 94992, 16778)
# joining in new circuit #16: (11183, 17766, 11176) (11838, 19540, 10195)
# joining in new circuit #17: (94302, 8407, 51987) (93570, 8142, 49999)
# joining in new circuit #18: (62600, 98360, 91994) (62303, 97857, 89910)
# joining in new circuit #19: (24988, 39612, 1029) (23094, 38540, 1003)
# joining in new circuit #20: (6885, 5471, 33589) (5015, 4559, 32673)
# joining in new circuit #21: (21540, 98996, 77215) (22563, 98366, 75251)
# joining in new circuit #22: (92324, 66957, 38440) (90594, 65338, 38344)
# joining in new circuit #23: (69723, 51975, 28799) (69102, 52284, 26518)
# joining in new circuit #24: (30426, 67953, 50954) (28988, 69581, 51939)
# joining in new circuit #25: (85879, 16155, 68927) (86644, 18413, 68809)
# joining in new circuit #26: (13042, 7553, 54947) (12200, 5333, 54643)
# joining in new circuit #27: (40350, 38071, 77312) (38764, 39852, 77546)
# joining in new circuit #28: (24128, 83397, 95380) (25028, 81131, 95733)
# joining in new circuit #29: (23680, 72684, 50502) (24111, 74954, 51360)
# joining in new circuit #30: (95652, 52936, 66151) (93335, 52489, 65428)
# joining in new circuit #31: (56810, 26386, 67508) (57972, 28578, 67304)
# joining in new circuit #32: (26818, 93175, 66675) (27921, 90943, 66682)
# joining in new circuit #33: (22288, 44073, 77841) (20702, 45662, 78958)
# joining in new circuit #34: (2690, 4326, 20803) (2642, 6715, 21579)
# joining in new circuit #35: (3862, 99779, 23671) (2167, 99436, 25535)
# joining in new circuit #36: (47059, 66430, 59047) (44545, 66073, 59746)
# joining pre-existing circuit #25: (83851, 16234, 67203)
# joining in new circuit #37: (23392, 87645, 17931) (24402, 85178, 18116)
# joining in new circuit #38: (68263, 7170, 41519) (70743, 6396, 40892)
# joining in new circuit #39: (77851, 75849, 81255) (75916, 75235, 79515)
# joining in new circuit #40: (80184, 11567, 9802) (78075, 12207, 11519)
# joining pre-existing circuit #28: (27259, 79400, 95967)
# joining in new circuit #41: (9101, 61740, 47697) (9806, 60823, 50299)
# joining in new circuit #42: (66881, 69410, 68483) (69728, 68868, 68611)
# joining in new circuit #43: (71769, 78077, 97079) (69819, 78591, 94976)
# joining in new circuit #44: (41716, 3182, 2052) (41476, 1171, 4195)
# joining in new circuit #45: (49059, 36258, 88309) (51978, 36024, 87919)
# joining in new circuit #46: (41695, 95037, 84822) (38914, 95962, 84436)
# joining in new circuit #47: (44383, 60208, 56605) (43488, 62443, 58347)
# joining in new circuit #48: (28468, 82028, 78202) (26932, 83645, 76200)
# joining in new circuit #49: (15144, 90763, 21475) (13627, 91894, 19150)
# joining in new circuit #50: (44963, 94576, 6752) (47573, 93324, 5817)
# joining in new circuit #51: (67858, 29769, 43483) (69431, 27247, 42783)
# joining in new circuit #52: (12525, 69643, 80364) (12150, 67733, 78002)
# joining pre-existing circuit #48: (31406, 81158, 78225)
# joining in new circuit #53: (6861, 93498, 70508) (3861, 93315, 69864)
# joining pre-existing circuit #37: (25313, 87508, 15533)
# joining in new circuit #54: (84092, 93252, 14143) (85453, 91128, 15949)
# joining in new circuit #55: (60309, 11479, 11660) (57335, 12420, 11406)
# joining pre-existing circuit #45: (48082, 33955, 90200)
# joining in new circuit #56: (65647, 85415, 67416) (64978, 85229, 64347)
# joining in new circuit #57: (76223, 44019, 45145) (75164, 46015, 42951)
# joining in new circuit #58: (25486, 79745, 52565) (23109, 81153, 51035)
# joining in new circuit #59: (35993, 38181, 88666) (33582, 40217, 88964)
# joining pre-existing circuit #24: (31883, 65301, 49971)
# joining in new circuit #60: (54019, 93581, 44124) (54931, 93845, 41070)
# joining in new circuit #61: (56078, 50898, 69520) (54520, 48125, 70320)
# joining in new circuit #62: (86483, 99542, 62061) (86331, 99017, 58826)
# joining pre-existing circuit #40: (79507, 8915, 7962)
# joining in new circuit #63: (50070, 64177, 69373) (50799, 61190, 70591)
# joining in new circuit #64: (2684, 14952, 48118) (5496, 14006, 49580)
# joining in new circuit #65: (40312, 28697, 48113) (38877, 26946, 45667)
# joining in new circuit #66: (70711, 22072, 76612) (69754, 18853, 76737)
# joining in new circuit #67: (42608, 60962, 52744) (45745, 60257, 51750)
# joining in new circuit #68: (64283, 24896, 73941) (62353, 22516, 75472)
# joining in new circuit #69: (13034, 51929, 5288) (15993, 53688, 5389)
# joining in new circuit #70: (17333, 38906, 58156) (15342, 36065, 57658)
# joining in new circuit #71: (91546, 65487, 12974) (94201, 63270, 12340)
# joining in new circuit #72: (1258, 10335, 99516) (291, 7063, 98623)
# joining in new circuit #73: (3036, 26773, 73089) (503, 24540, 74109)
# joining in new circuit #74: (98222, 66928, 58170) (96867, 63697, 57587)
# joining pre-existing circuit #30: (98236, 55210, 65140)
# joining pre-existing circuit #68: (58945, 21508, 74957)
# skip. elements (25313, 87508, 15533) and (24402, 85178, 18116) already part of circuit 37
# joining in new circuit #75: (55440, 87576, 5651) (56793, 88894, 2566)
# joining in new circuit #76: (28756, 38533, 3449) (31754, 38857, 5472)
# joining in new circuit #77: (77504, 54363, 2998) (75596, 57314, 2080)
# joining in new circuit #78: (74136, 31617, 52343) (73682, 33340, 55513)
# joining in new circuit #79: (78631, 79784, 39322) (77655, 76601, 40836)
# joining pre-existing circuit #65: (38744, 31413, 46215)
# joining in new circuit #80: (50900, 67651, 35035) (50257, 64793, 32815)
# joining in new circuit #81: (30351, 24409, 71865) (32560, 25048, 74746)
# joining in new circuit #82: (76450, 91507, 56306) (77994, 89664, 53497)
# joining in new circuit #83: (89146, 28704, 75660) (90335, 31355, 73367)
# joining in new circuit #84: (87395, 46229, 13760) (87992, 49889, 13937)
# joining in new circuit #85: (60863, 32475, 12328) (57411, 32140, 13666)
# joining in new circuit #86: (52305, 27711, 12276) (50539, 26103, 9419)
# joining in new circuit #87: (51684, 27034, 46142) (51213, 24201, 48521)
# joining in new circuit #88: (59642, 49413, 22350) (61110, 50628, 25583)
# joining pre-existing circuit #43: (71376, 82006, 94810)
# joining in new circuit #89: (4449, 91079, 73396) (6372, 89533, 76248)
# joining in new circuit #90: (52120, 41630, 79388) (52239, 44390, 81971)
# joining pre-existing circuit #51: (70688, 31276, 41458)
# joining in new circuit #91: (26287, 44613, 75811) (26462, 46810, 78911)
# joining in new circuit #92: (6031, 13077, 81006) (4082, 11372, 78212)
# joining pre-existing circuit #3: (16315, 16447, 35696)
# joining pre-existing circuit #85: (62260, 32976, 15843)
# joining in new circuit #93: (18132, 37987, 2681) (19788, 35881, 5406)
# joining in new circuit #94: (19282, 12366, 5797) (17737, 15580, 7171)
# joining in new circuit #95: (41979, 37643, 30905) (44048, 38624, 33976)
# joining in new circuit #96: (74861, 52125, 10889) (77085, 50590, 13612)
# joining in new circuit #97: (98304, 65923, 47048) (99563, 63860, 50034)
# joining in new circuit #98: (51719, 96445, 32951) (49260, 97037, 35856)
# joining in new circuit #99: (97700, 55713, 85972) (96001, 59106, 86745)
# joining pre-existing circuit #56: (62172, 83553, 66445)
# skip. elements (83851, 16234, 67203) and (86644, 18413, 68809) already part of circuit 25
# joining in new circuit #100: (38540, 40859, 44578) (39361, 44695, 44520)
# joining pre-existing circuit #51: (66394, 26566, 40388)
# joining pre-existing circuit #26: (12385, 5178, 58572)
# joining pre-existing circuit #56: (64073, 84972, 60519)
# joining pre-existing circuit #5: (82559, 82014, 26788)
# joining in new circuit #101: (83499, 75069, 28719) (83952, 76135, 24942)
# joining in new circuit #102: (50768, 46209, 29535) (48312, 43149, 29000)
# joining in new circuit #103: (60777, 85640, 48029) (60066, 86431, 51852)
# joining pre-existing circuit #76: (31953, 35585, 7710)
# joining in new circuit #104: (31359, 63508, 57453) (33132, 65203, 60582)
# joining in new circuit #105: (16696, 43417, 30536) (19403, 40600, 31323)
# joining circuits 36 (n=2) and 47 (n=2) in 36
# new len of circuit 36 (n=4)
# joining in new circuit #106: (61373, 81011, 98751) (59531, 80072, 95289)
# joining pre-existing circuit #60: (50725, 91581, 42922)
# joining pre-existing circuit #85: (60234, 36470, 16079)
# joining pre-existing circuit #25: (80821, 15501, 64608)
# skip. elements (65647, 85415, 67416) and (62172, 83553, 66445) already part of circuit 56
# joining in new circuit #107: (90834, 43104, 41436) (88506, 46179, 40108)
# joining in new circuit #108: (45142, 41794, 73641) (46132, 42816, 69813)
# joining in new circuit #109: (37355, 30445, 38934) (37317, 28660, 35244)
# joining in new circuit #110: (40531, 51036, 42979) (40237, 51779, 47009)
# joining in new circuit #111: (48602, 57813, 21435) (51913, 55474, 22126)
# joining pre-existing circuit #57: (72665, 42120, 46057)
# joining in new circuit #112: (43949, 56387, 38313) (45635, 60095, 37602)
# joining in new circuit #113: (78827, 49932, 19120) (80536, 53022, 21301)
# joining in new circuit #114: (86567, 6031, 78768) (83460, 8483, 80043)
# joining in new circuit #115: (15310, 4035, 36063) (18655, 1950, 34729)
# joining in new circuit #116: (21095, 68703, 32667) (18807, 66871, 35623)
# joining pre-existing circuit #59: (30941, 41866, 91750)
# joining pre-existing circuit #41: (6372, 60266, 52651)
# joining circuits 89 (n=2) and 53 (n=2) in 89
# new len of circuit 89 (n=4)
# joining pre-existing circuit #52: (9342, 64901, 76610)
# joining pre-existing circuit #95: (46372, 36222, 31378)
# joining in new circuit #117: (48513, 7420, 41917) (51332, 6299, 44884)
# joining in new circuit #118: (25020, 83317, 27588) (22399, 86497, 26465)
# joining in new circuit #119: (9319, 71625, 7443) (10175, 70106, 11380)
# joining pre-existing circuit #52: (9438, 62028, 73398)
# joining pre-existing circuit #3: (10837, 20258, 31823)
# joining circuits 67 (n=2) and 36 (n=4) in 67
# new len of circuit 67 (n=6)
# joining in new circuit #120: (3018, 85219, 38426) (458, 84406, 41805)
# joining in new circuit #121: (18508, 73851, 20706) (22742, 73410, 19960)
# joining in new circuit #122: (8748, 38139, 17986) (9384, 36772, 13933)
# joining in new circuit #123: (55311, 27129, 22804) (53777, 23102, 22439)
# joining in new circuit #124: (83081, 893, 31822) (83970, 5105, 32291)
# joining pre-existing circuit #5: (84739, 82331, 30534)
# joining in new circuit #125: (5808, 46574, 99877) (9738, 45747, 98205)
# joining in new circuit #126: (36384, 55159, 44483) (37813, 59031, 43104)
# joining in new circuit #127: (83158, 32854, 75751) (82941, 28516, 76078)
# joining in new circuit #128: (666, 14050, 81604) (259, 12830, 85774)
# joining pre-existing circuit #97: (99323, 62842, 44115)
# skip. elements (12385, 5178, 58572) and (13042, 7553, 54947) already part of circuit 26
# joining in new circuit #129: (43346, 71378, 74054) (46415, 70487, 71036)
# joining pre-existing circuit #78: (76148, 27834, 51308)
# joining in new circuit #130: (9331, 97409, 54972) (6867, 94678, 57404)
# joining pre-existing circuit #86: (52080, 22567, 11571)
# joining pre-existing circuit #49: (17421, 89336, 24983)
# joining in new circuit #131: (87712, 1282, 50859) (87161, 1860, 55207)
# skip. elements (69431, 27247, 42783) and (70688, 31276, 41458) already part of circuit 51
# joining pre-existing circuit #86: (47365, 27230, 12297)
# joining in new circuit #132: (53949, 83540, 13930) (55023, 84773, 18064)
# joining pre-existing circuit #81: (33002, 21084, 76725)
# skip. elements (4449, 91079, 73396) and (6861, 93498, 70508) already part of circuit 89
# joining in new circuit #133: (33262, 27376, 60923) (36418, 24667, 62597)
# skip. elements (15380, 19660, 32704) and (16315, 16447, 35696) already part of circuit 3
# joining in new circuit #134: (43387, 51638, 15308) (40564, 48148, 15198)
# joining pre-existing circuit #113: (84617, 54869, 21689)
# skip. elements (38744, 31413, 46215) and (38877, 26946, 45667) already part of circuit 65
# joining in new circuit #135: (87517, 69583, 83857) (88452, 67409, 80013)
# joining pre-existing circuit #81: (26727, 24788, 69200)
# joining circuits 33 (n=2) and 91 (n=2) in 33
# new len of circuit 33 (n=4)
# joining pre-existing circuit #114: (88377, 1899, 79133)
# skip. elements (71769, 78077, 97079) and (71376, 82006, 94810) already part of circuit 43
# joining pre-existing circuit #60: (58280, 91324, 39288)
# joining pre-existing circuit #90: (55300, 47777, 81960)
# joining pre-existing circuit #94: (23420, 14193, 6451)
# joining in new circuit #136: (55372, 69770, 64512) (55087, 65940, 62025)
# joining in new circuit #137: (8757, 42724, 65751) (7870, 39897, 62259)
# joining in new circuit #138: (66723, 3839, 80733) (63092, 3629, 83534)
# joining in new circuit #139: (65980, 47047, 73819) (66636, 46552, 69301)
# joining in new circuit #140: (48074, 1683, 74009) (44494, 380, 76584)
# joining pre-existing circuit #3: (6530, 21872, 31721)
# joining pre-existing circuit #42: (69981, 72837, 70933)
# joining in new circuit #141: (80861, 7844, 42700) (77611, 4665, 43435)
# joining circuits 19 (n=2) and 76 (n=3) in 19
# new len of circuit 19 (n=5)
# joining pre-existing circuit #141: (74951, 3504, 47016)
# joining pre-existing circuit #9: (90094, 67670, 3026)
# skip. elements (41979, 37643, 30905) and (46372, 36222, 31378) already part of circuit 95
# skip. elements (15380, 19660, 32704) and (10837, 20258, 31823) already part of circuit 3
# skip. elements (66394, 26566, 40388) and (67858, 29769, 43483) already part of circuit 51
# joining in new circuit #142: (74406, 27244, 68191) (77575, 23913, 69122)
# joining in new circuit #143: (60299, 69835, 32060) (59894, 65987, 29384)
# joining pre-existing circuit #60: (57886, 97171, 39530)
# joining in new circuit #144: (84920, 17068, 46084) (80915, 18868, 44374)
# joining pre-existing circuit #139: (69391, 44014, 72631)
# joining in new circuit #145: (32286, 93308, 37900) (30246, 89041, 37943)
# joining pre-existing circuit #56: (59620, 79827, 67874)
# joining in new circuit #146: (95286, 25248, 27110) (90887, 26456, 25793)
# joining in new circuit #147: (72248, 37051, 58336) (71389, 35612, 62781)
# joining in new circuit #148: (72474, 33164, 17075) (76473, 34178, 14714)
# joining in new circuit #149: (1834, 68498, 62134) (3198, 67912, 66650)
# joining in new circuit #150: (47666, 963, 22625) (49729, 2441, 18565)
# joining pre-existing circuit #15: (53222, 93360, 12407)
# joining in new circuit #151: (4283, 41791, 17248) (1497, 44829, 14733)
# joining pre-existing circuit #44: (39774, 6245, 5262)
# joining pre-existing circuit #112: (48458, 62910, 40354)
# joining in new circuit #152: (97508, 31301, 58940) (93148, 31588, 56803)
# joining in new circuit #153: (3762, 25398, 16688) (1244, 25584, 12520)
# joining pre-existing circuit #119: (13866, 72451, 8994)
# joining circuits 147 (n=2) and 78 (n=3) in 147
# new len of circuit 147 (n=5)
# joining pre-existing circuit #116: (23935, 72205, 34540)
# joining pre-existing circuit #20: (965, 3575, 35223)
# joining pre-existing circuit #46: (35653, 98966, 82326)
# joining in new circuit #154: (95133, 9688, 11415) (98149, 7424, 8264)
# joining pre-existing circuit #65: (44178, 31486, 49318)
# skip. elements (82215, 83791, 22210) and (82559, 82014, 26788) already part of circuit 5
# joining pre-existing circuit #111: (55411, 58938, 21882)
# joining in new circuit #155: (91872, 72848, 67899) (88593, 76147, 69533)
# joining in new circuit #156: (34326, 45305, 71576) (35179, 49837, 73336)
# joining in new circuit #157: (77539, 61583, 62444) (78570, 59051, 66557)
# joining pre-existing circuit #19: (20483, 42652, 1866)
# joining in new circuit #158: (97169, 6694, 35033) (96159, 11515, 34424)
# skip. elements (52305, 27711, 12276) and (47365, 27230, 12297) already part of circuit 86
# skip. elements (48082, 33955, 90200) and (51978, 36024, 87919) already part of circuit 45
# joining pre-existing circuit #114: (78681, 9149, 81227)
# joining pre-existing circuit #25: (78333, 17120, 60613)
# skip. elements (10175, 70106, 11380) and (13866, 72451, 8994) already part of circuit 119
# joining in new circuit #159: (55356, 11885, 96922) (54345, 7281, 98557)
# joining pre-existing circuit #37: (30243, 87825, 16291)
# joining pre-existing circuit #60: (57063, 89270, 43680)
# joining in new circuit #160: (94059, 62070, 80975) (94822, 60653, 76242)
# joining pre-existing circuit #159: (50453, 12604, 96216)
# joining in new circuit #161: (94562, 95663, 57630) (90713, 94244, 54761)
# skip. elements (66636, 46552, 69301) and (69391, 44014, 72631) already part of circuit 139
# joining in new circuit #162: (12636, 6314, 70948) (11644, 10448, 73642)
# joining pre-existing circuit #68: (61871, 28559, 71466)
# joining in new circuit #163: (26492, 92665, 59432) (27936, 94726, 55068)
# skip. elements (44383, 60208, 56605) and (45745, 60257, 51750) already part of circuit 67
# joining in new circuit #164: (32423, 31757, 41456) (34391, 36299, 40481)
# joining pre-existing circuit #22: (88516, 63642, 42624)
# joining in new circuit #165: (7837, 15891, 68925) (4387, 19502, 69689)
# skip. elements (79507, 8915, 7962) and (78075, 12207, 11519) already part of circuit 40
# joining pre-existing circuit #5: (82046, 88064, 19470)
# joining in new circuit #166: (37419, 77779, 70129) (41845, 80240, 70516)
# joining pre-existing circuit #45: (45170, 34770, 85383)
# joining pre-existing circuit #131: (89576, 4950, 58464)
# skip. elements (22288, 44073, 77841) and (26462, 46810, 78911) already part of circuit 33
# joining pre-existing circuit #129: (51416, 70759, 70043)
# joining pre-existing circuit #7: (68810, 15753, 68290)
# skip. elements (27259, 79400, 95967) and (24128, 83397, 95380) already part of circuit 28
# skip. elements (54931, 93845, 41070) and (50725, 91581, 42922) already part of circuit 60
# joining circuits 58 (n=2) and 29 (n=2) in 58
# new len of circuit 58 (n=4)
# joining pre-existing circuit #106: (64002, 81020, 92955)
# joining in new circuit #167: (81608, 93167, 44138) (82691, 92615, 39146)
# joining in new circuit #168: (90991, 97656, 33346) (95670, 96447, 31587)
# joining pre-existing circuit #136: (59770, 71782, 62761)
# joining in new circuit #169: (26363, 22436, 18250) (28967, 18083, 17390)
# joining pre-existing circuit #71: (98743, 60846, 12266)
# joining pre-existing circuit #94: (20435, 12775, 10812)
# joining pre-existing circuit #156: (39415, 44712, 72242)
# joining pre-existing circuit #86: (48466, 27321, 17352)
# joining in new circuit #170: (43507, 63953, 33507) (41088, 66609, 37234)
# joining pre-existing circuit #134: (36361, 45237, 14358)
# joining in new circuit #171: (87725, 55047, 64862) (85555, 56271, 69415)
# skip. elements (52305, 27711, 12276) and (52080, 22567, 11571) already part of circuit 86
# joining in new circuit #172: (94855, 64031, 65192) (94403, 64316, 70380)
# joining in new circuit #173: (99369, 32220, 91097) (98834, 27441, 93123)
# skip. elements (66881, 69410, 68483) and (69981, 72837, 70933) already part of circuit 42
# joining pre-existing circuit #42: (74615, 68965, 70476)
# joining in new circuit #174: (5580, 45890, 53641) (10744, 45392, 54405)
# joining in new circuit #175: (78438, 80566, 65309) (77931, 78942, 70270)
# joining in new circuit #176: (5643, 32576, 66388) (10755, 31956, 65376)
# joining pre-existing circuit #60: (53980, 88653, 37844)
# joining in new circuit #177: (66076, 94719, 74277) (66649, 95496, 79453)
# joining in new circuit #178: (28839, 16674, 88793) (33275, 17698, 91440)
# skip. elements (90094, 67670, 3026) and (93976, 70443, 5258) already part of circuit 9
# joining circuits 19 (n=6) and 93 (n=2) in 19
# new len of circuit 19 (n=8)
# joining in new circuit #179: (26604, 17867, 63450) (25381, 12906, 64780)
# skip. elements (20483, 42652, 1866) and (18132, 37987, 2681) already part of circuit 19
# skip. elements (57063, 89270, 43680) and (54019, 93581, 44124) already part of circuit 60
# joining pre-existing circuit #162: (9568, 7227, 77305)
# joining pre-existing circuit #66: (73582, 25537, 73783)
# joining in new circuit #180: (27155, 89120, 84852) (30785, 90334, 81150)
# skip. elements (20435, 12775, 10812) and (17737, 15580, 7171) already part of circuit 94
# joining in new circuit #181: (47672, 7659, 66653) (42964, 5801, 68393)
# joining in new circuit #182: (40042, 93155, 70842) (43041, 90787, 67075)
# joining in new circuit #183: (17777, 85013, 42243) (14262, 81005, 42933)
# joining in new circuit #184: (12575, 52169, 37052) (11977, 47032, 38528)
# skip. elements (57411, 32140, 13666) and (62260, 32976, 15843) already part of circuit 85
# joining in new circuit #185: (23031, 22842, 61404) (18942, 19759, 59728)
# joining pre-existing circuit #167: (87287, 95053, 37710)
# joining pre-existing circuit #151: (4089, 48364, 11583)
# skip. elements (47059, 66430, 59047) and (43488, 62443, 58347) already part of circuit 67
# joining pre-existing circuit #4: (39389, 64654, 11095)
# joining in new circuit #186: (43518, 1650, 46267) (46685, 2191, 50624)
# joining in new circuit #187: (25335, 89999, 41693) (28381, 91487, 45923)
# joining in new circuit #188: (61257, 96072, 80693) (60105, 95545, 75417)
# joining pre-existing circuit #67: (47084, 59518, 61262)
# joining pre-existing circuit #32: (32817, 88581, 66462)
# joining pre-existing circuit #144: (82250, 20965, 39533)
# joining in new circuit #189: (17268, 92676, 60622) (18542, 92605, 65918)
# joining pre-existing circuit #16: (15446, 22659, 7551)
# joining pre-existing circuit #138: (68954, 2117, 76061)
# skip. elements (39774, 6245, 5262) and (41476, 1171, 4195) already part of circuit 44
# joining in new circuit #190: (29021, 30279, 82178) (32570, 26366, 80757)
# skip. elements (23420, 14193, 6451) and (20435, 12775, 10812) already part of circuit 94
# joining in new circuit #191: (37903, 76448, 28218) (41718, 76694, 32138)
# skip. elements (47084, 59518, 61262) and (43488, 62443, 58347) already part of circuit 67
# joining in new circuit #192: (35464, 59964, 83167) (30604, 60970, 85499)
# joining circuits 92 (n=2) and 128 (n=2) in 92
# new len of circuit 92 (n=4)
# joining pre-existing circuit #48: (34925, 84588, 80670)
# joining in new circuit #193: (86689, 26472, 19922) (82320, 25476, 23092)
# skip. elements (24988, 39612, 1029) and (20483, 42652, 1866) already part of circuit 19
# joining in new circuit #194: (34744, 13511, 14315) (36252, 18643, 15609)
# skip. elements (31406, 81158, 78225) and (26932, 83645, 76200) already part of circuit 48
# joining pre-existing circuit #54: (88069, 87088, 13271)
# skip. elements (4082, 11372, 78212) and (666, 14050, 81604) already part of circuit 92
# joining pre-existing circuit #126: (32449, 58575, 46291)
# skip. elements (60863, 32475, 12328) and (60234, 36470, 16079) already part of circuit 85
# joining pre-existing circuit #3: (19442, 20922, 36521)
# skip. elements (31883, 65301, 49971) and (28988, 69581, 51939) already part of circuit 24
# joining pre-existing circuit #82: (80660, 94091, 51503)
# joining in new circuit #195: (18726, 20371, 84504) (19090, 20548, 90036)
# joining pre-existing circuit #88: (62879, 54752, 22318)
# joining pre-existing circuit #12: (95612, 1796, 76085)
# joining circuits 188 (n=2) and 177 (n=2) in 188
# new len of circuit 188 (n=4)
# joining pre-existing circuit #86: (43576, 28244, 19849)
# skip. elements (72665, 42120, 46057) and (75164, 46015, 42951) already part of circuit 57
# joining in new circuit #196: (20863, 60860, 95233) (20608, 61733, 89729)
# joining in new circuit #197: (10866, 49642, 65952) (7554, 47005, 62304)
# joining circuits 2 (n=2) and 191 (n=2) in 2
# new len of circuit 2 (n=4)
# joining pre-existing circuit #63: (55341, 63220, 67780)
# joining pre-existing circuit #32: (32337, 94052, 65219)
# joining pre-existing circuit #192: (39686, 57913, 80120)
# joining pre-existing circuit #4: (33254, 64716, 3171)
# skip. elements (98236, 55210, 65140) and (93335, 52489, 65428) already part of circuit 30
# joining pre-existing circuit #65: (48434, 33151, 52578)
# joining in new circuit #198: (88830, 72652, 76447) (83580, 73457, 74629)
# joining pre-existing circuit #140: (51518, 4827, 77147)
# joining circuits 10 (n=2) and 38 (n=2) in 10
# new len of circuit 10 (n=4)
# joining circuits 137 (n=2) and 197 (n=2) in 137
# new len of circuit 137 (n=4)
# joining pre-existing circuit #70: (9765, 36804, 57491)
# skip. elements (32817, 88581, 66462) and (32337, 94052, 65219) already part of circuit 32
# joining pre-existing circuit #13: (96449, 26911, 46011)
# joining pre-existing circuit #60: (47175, 93843, 46676)
# joining pre-existing circuit #129: (47743, 71301, 77615)
# joining pre-existing circuit #105: (19706, 36855, 27077)
# joining pre-existing circuit #195: (22197, 19367, 80130)
# joining in new circuit #199: (80772, 13542, 99369) (78553, 16763, 95257)
# skip. elements (57063, 89270, 43680) and (54931, 93845, 41070) already part of circuit 60
# joining pre-existing circuit #3: (18940, 17486, 41020)
# joining pre-existing circuit #175: (83138, 83683, 64589)
# joining pre-existing circuit #72: (4432, 3412, 97257)
# skip. elements (48082, 33955, 90200) and (45170, 34770, 85383) already part of circuit 45
# joining in new circuit #200: (30147, 42821, 59289) (28561, 41293, 64536)
# joining circuits 109 (n=2) and 164 (n=2) in 109
# new len of circuit 109 (n=4)
# joining pre-existing circuit #193: (81848, 22092, 18531)
# joining circuits 31 (n=2) and 68 (n=4) in 31
# new len of circuit 31 (n=6)
# skip. elements (57411, 32140, 13666) and (60234, 36470, 16079) already part of circuit 85
# joining circuits 126 (n=3) and 110 (n=2) in 126
# new len of circuit 126 (n=5)
# skip. elements (55341, 63220, 67780) and (50799, 61190, 70591) already part of circuit 63
# skip. elements (19442, 20922, 36521) and (15380, 19660, 32704) already part of circuit 3
# joining pre-existing circuit #100: (33790, 42653, 47210)
# joining pre-existing circuit #41: (9564, 55512, 52463)
# skip. elements (43033, 72228, 28791) and (41718, 76694, 32138) already part of circuit 2
# skip. elements (9564, 55512, 52463) and (9806, 60823, 50299) already part of circuit 41
# joining pre-existing circuit #60: (54710, 91525, 32927)
# joining pre-existing circuit #122: (12795, 34073, 18223)
# joining circuits 60 (n=9) and 98 (n=2) in 60
# new len of circuit 60 (n=11)
# joining in new circuit #201: (86567, 78205, 79040) (89698, 81111, 82903)
# joining pre-existing circuit #34: (2046, 6709, 15596)
# skip. elements (33254, 64716, 3171) and (37722, 67135, 5895) already part of circuit 4
# joining in new circuit #202: (90028, 4821, 34749) (89537, 10541, 35315)
# joining pre-existing circuit #198: (81694, 68822, 77506)
# skip. elements (26818, 93175, 66675) and (32337, 94052, 65219) already part of circuit 32
# joining circuits 5 (n=5) and 54 (n=3) in 5
# new len of circuit 5 (n=8)
# joining in new circuit #203: (76360, 73922, 95444) (79816, 73536, 90823)
# joining pre-existing circuit #139: (74542, 43803, 69982)
# joining pre-existing circuit #111: (60778, 59712, 19832)
# joining in new circuit #204: (76766, 11529, 92803) (74763, 14138, 88025)
# joining pre-existing circuit #127: (80325, 28120, 81243)
# joining circuits 113 (n=3) and 96 (n=2) in 113
# new len of circuit 113 (n=5)
# joining circuits 151 (n=3) and 122 (n=3) in 151
# new len of circuit 151 (n=6)
# joining pre-existing circuit #180: (25500, 94661, 85585)
# joining pre-existing circuit #152: (95439, 29383, 51917)
# joining pre-existing circuit #156: (33004, 44533, 77204)
# joining in new circuit #205: (67452, 7760, 53462) (64925, 3356, 56346)
# joining pre-existing circuit #51: (68658, 24431, 35445)
# joining pre-existing circuit #11: (6886, 7827, 1340)
# joining in new circuit #206: (1300, 16686, 13908) (4756, 18514, 9565)
# joining in new circuit #207: (69005, 69550, 48367) (65223, 73662, 50082)
# skip. elements (9101, 61740, 47697) and (6372, 60266, 52651) already part of circuit 41
# joining pre-existing circuit #172: (89696, 65504, 73650)
# joining pre-existing circuit #121: (19940, 69970, 16140)
# skip. elements (42608, 60962, 52744) and (43488, 62443, 58347) already part of circuit 67
# joining in new circuit #208: (48588, 40762, 44917) (52722, 43187, 48295)
# skip. elements (58280, 91324, 39288) and (57886, 97171, 39530) already part of circuit 60
# joining pre-existing circuit #138: (67354, 6389, 86477)
# skip. elements (26462, 46810, 78911) and (20702, 45662, 78958) already part of circuit 33
# joining in new circuit #209: (33258, 74994, 64527) (30595, 76448, 59496)
# joining in new circuit #210: (31307, 13092, 78503) (27388, 16669, 75980)
# joining pre-existing circuit #56: (65080, 88377, 55837)
# joining in new circuit #211: (26485, 51273, 36382) (26083, 48233, 41397)
# joining pre-existing circuit #155: (85125, 77278, 64918)
# joining in new circuit #212: (33310, 78787, 40042) (31725, 81398, 35009)
# joining pre-existing circuit #65: (42081, 34984, 53573)
# skip. elements (23420, 14193, 6451) and (17737, 15580, 7171) already part of circuit 94
# joining in new circuit #213: (93227, 36179, 30343) (90468, 38717, 25785)
# joining circuits 142 (n=2) and 66 (n=3) in 142
# new len of circuit 142 (n=5)
# joining in new circuit #214: (43046, 64794, 20259) (40128, 69529, 22244)
# joining in new circuit #215: (42293, 4860, 27491) (47350, 2431, 29370)
# joining circuits 49 (n=3) and 118 (n=2) in 49
# new len of circuit 49 (n=5)
# joining pre-existing circuit #144: (85889, 20714, 50647)
# joining circuits 111 (n=4) and 88 (n=3) in 111
# new len of circuit 111 (n=7)
# joining in new circuit #216: (41289, 13109, 52369) (45332, 17223, 53769)
# joining in new circuit #217: (96954, 91389, 88406) (96165, 95188, 83851)
# joining in new circuit #218: (30741, 50346, 67279) (34841, 47498, 63972)
# joining circuits 70 (n=3) and 137 (n=4) in 70
# new len of circuit 70 (n=7)
# joining pre-existing circuit #63: (55303, 59740, 62898)
# skip. elements (39389, 64654, 11095) and (37722, 67135, 5895) already part of circuit 4
# joining pre-existing circuit #34: (2619, 5614, 9718)
# joining pre-existing circuit #133: (41352, 27805, 61213)
# skip. elements (99323, 62842, 44115) and (99563, 63860, 50034) already part of circuit 97
# joining pre-existing circuit #165: (3821, 19731, 75670)
# skip. elements (2642, 6715, 21579) and (2046, 6709, 15596) already part of circuit 34
# joining circuits 170 (n=2) and 112 (n=3) in 170
# new len of circuit 170 (n=5)
# skip. elements (18940, 17486, 41020) and (16315, 16447, 35696) already part of circuit 3
# skip. elements (36384, 55159, 44483) and (40531, 51036, 42979) already part of circuit 126
# joining pre-existing circuit #172: (93331, 58423, 69568)
# joining circuits 73 (n=2) and 165 (n=3) in 73
# new len of circuit 73 (n=5)
# joining circuits 204 (n=2) and 199 (n=2) in 204
# new len of circuit 204 (n=4)
# skip. elements (74615, 68965, 70476) and (69981, 72837, 70933) already part of circuit 42
# joining pre-existing circuit #77: (78822, 49482, 6336)
# joining in new circuit #219: (23002, 52101, 58177) (21133, 46372, 57543)
# joining pre-existing circuit #188: (65640, 89906, 81564)
# joining pre-existing circuit #205: (68628, 566, 60269)
# joining pre-existing circuit #14: (39992, 50610, 86416)
# skip. elements (68263, 7170, 41519) and (64584, 11393, 39148) already part of circuit 10
# skip. elements (28756, 38533, 3449) and (31953, 35585, 7710) already part of circuit 19
# joining pre-existing circuit #82: (72573, 87121, 52368)
# joining in new circuit #220: (47601, 61891, 11199) (53666, 61645, 11746)
# skip. elements (12795, 34073, 18223) and (9384, 36772, 13933) already part of circuit 151
# joining pre-existing circuit #153: (1374, 25658, 22310)
# skip. elements (23094, 38540, 1003) and (19788, 35881, 5406) already part of circuit 19
# joining pre-existing circuit #10: (62483, 8660, 44213)
# joining in new circuit #221: (47675, 97068, 17377) (49961, 98217, 22947)
# joining pre-existing circuit #52: (7037, 58510, 77807)
# skip. elements (60105, 95545, 75417) and (66076, 94719, 74277) already part of circuit 188
# joining pre-existing circuit #9: (98582, 74470, 5749)
# joining in new circuit #222: (15292, 28195, 69720) (16781, 22272, 70443)
# joining circuits 190 (n=2) and 81 (n=4) in 190
# new len of circuit 190 (n=6)
# joining in new circuit #223: (26867, 79978, 43339) (26953, 73826, 43070)
# skip. elements (19442, 20922, 36521) and (14656, 18849, 33244) already part of circuit 3
# skip. elements (19940, 69970, 16140) and (18508, 73851, 20706) already part of circuit 121
# skip. elements (23094, 38540, 1003) and (28756, 38533, 3449) already part of circuit 19
# joining pre-existing circuit #213: (97560, 40554, 29866)
# joining in new circuit #224: (24969, 64263, 8780) (19343, 62983, 6569)
# skip. elements (54931, 93845, 41070) and (53980, 88653, 37844) already part of circuit 60
# joining circuits 171 (n=2) and 30 (n=3) in 171
# new len of circuit 171 (n=5)
# joining circuits 7 (n=3) and 31 (n=6) in 7
# new len of circuit 7 (n=9)
# joining in new circuit #225: (27272, 23697, 53607) (32122, 22134, 50070)
# joining in new circuit #226: (50791, 21303, 89777) (44615, 21549, 90371)
# joining circuits 127 (n=3) and 83 (n=2) in 127
# new len of circuit 127 (n=5)
# joining pre-existing circuit #92: (896, 12924, 73091)
# joining pre-existing circuit #0: (20013, 2042, 3974)
# joining pre-existing circuit #105: (15378, 32488, 26055)
# joining pre-existing circuit #140: (57428, 4118, 78998)
# joining pre-existing circuit #63: (44902, 59402, 71547)
# skip. elements (59642, 49413, 22350) and (62879, 54752, 22318) already part of circuit 111
# joining in new circuit #227: (51669, 69871, 88535) (50217, 63804, 88237)
# joining circuits 187 (n=2) and 145 (n=2) in 187
# new len of circuit 187 (n=4)
# skip. elements (32449, 58575, 46291) and (37813, 59031, 43104) already part of circuit 126
# skip. elements (44178, 31486, 49318) and (38744, 31413, 46215) already part of circuit 65
# joining circuits 63 (n=5) and 136 (n=3) in 63
# new len of circuit 63 (n=8)
# joining pre-existing circuit #65: (44636, 40643, 54413)
# skip. elements (81678, 82926, 23052) and (82046, 88064, 19470) already part of circuit 5
# joining pre-existing circuit #59: (32697, 38798, 96934)
# joining pre-existing circuit #90: (53106, 35435, 79550)
# joining in new circuit #228: (33503, 26890, 9727) (28048, 25636, 6882)
# joining in new circuit #229: (20122, 97509, 28709) (18767, 96970, 34824)
# skip. elements (24111, 74954, 51360) and (23109, 81153, 51035) already part of circuit 58
# joining circuits 168 (n=2) and 167 (n=3) in 168
# new len of circuit 168 (n=5)
# joining in new circuit #230: (21861, 31642, 21805) (18369, 26440, 22376)
# joining pre-existing circuit #51: (68676, 26478, 29494)
# skip. elements (53222, 93360, 12407) and (57450, 94992, 16778) already part of circuit 15
# joining pre-existing circuit #169: (20705, 22689, 15485)
# joining pre-existing circuit #192: (39165, 57781, 87780)
# joining circuits 24 (n=3) and 58 (n=4) in 24
# new len of circuit 24 (n=7)
# joining in new circuit #231: (8416, 93605, 35726) (9360, 97954, 31246)
# skip. elements (66723, 3839, 80733) and (67354, 6389, 86477) already part of circuit 138
# joining circuits 5 (n=8) and 101 (n=2) in 5
# new len of circuit 5 (n=10)
# skip. elements (95612, 1796, 76085) and (96149, 7722, 78223) already part of circuit 12
# joining in new circuit #232: (7626, 50516, 23858) (8289, 48158, 18027)
# joining pre-existing circuit #198: (75873, 66534, 78556)
# skip. elements (73582, 25537, 73783) and (77575, 23913, 69122) already part of circuit 142
# skip. elements (96449, 26911, 46011) and (99950, 22091, 48206) already part of circuit 13
# joining circuits 198 (n=4) and 135 (n=2) in 198
# new len of circuit 198 (n=6)
# joining pre-existing circuit #198: (84150, 65244, 87060)
# joining pre-existing circuit #65: (38658, 20810, 47329)
# skip. elements (61373, 81011, 98751) and (64002, 81020, 92955) already part of circuit 106
# skip. elements (55341, 63220, 67780) and (55087, 65940, 62025) already part of circuit 63
# skip. elements (52305, 27711, 12276) and (48466, 27321, 17352) already part of circuit 86
# joining pre-existing circuit #63: (59701, 71836, 56383)
# skip. elements (64073, 84972, 60519) and (62172, 83553, 66445) already part of circuit 56
# joining pre-existing circuit #141: (85072, 12159, 40585)
# joining pre-existing circuit #209: (36175, 72813, 59266)
# skip. elements (64283, 24896, 73941) and (58945, 21508, 74957) already part of circuit 7
# joining circuits 43 (n=3) and 203 (n=2) in 43
# new len of circuit 43 (n=5)
# skip. elements (22662, 6955, 7124) and (20013, 2042, 3974) already part of circuit 0
# skip. elements (6885, 5471, 33589) and (965, 3575, 35223) already part of circuit 20
# joining pre-existing circuit #129: (39088, 73199, 78519)
# joining in new circuit #233: (94837, 13205, 85733) (93440, 8114, 89428)
# joining pre-existing circuit #154: (99284, 11259, 16097)
# skip. elements (30351, 24409, 71865) and (33002, 21084, 76725) already part of circuit 190
# joining circuits 179 (n=2) and 185 (n=2) in 179
# new len of circuit 179 (n=4)
# joining pre-existing circuit #24: (24114, 67884, 46203)
# skip. elements (66394, 26566, 40388) and (70688, 31276, 41458) already part of circuit 51
# joining pre-existing circuit #64: (1493, 9272, 45268)
# joining in new circuit #234: (58380, 29471, 46772) (63145, 27962, 50896)
# joining circuits 152 (n=3) and 13 (n=3) in 152
# new len of circuit 152 (n=6)
# joining in new circuit #235: (14552, 95414, 5426) (18067, 90770, 2553)
# skip. elements (26287, 44613, 75811) and (20702, 45662, 78958) already part of circuit 33
# joining pre-existing circuit #5: (77013, 75427, 28821)
# joining pre-existing circuit #61: (52444, 51421, 75529)
# joining pre-existing circuit #111: (44672, 59870, 26203)
# skip. elements (33790, 42653, 47210) and (39361, 44695, 44520) already part of circuit 100
# joining pre-existing circuit #50: (41080, 99019, 3988)
# joining circuits 94 (n=4) and 0 (n=3) in 94
# new len of circuit 94 (n=7)
# skip. elements (63502, 18502, 70887) and (68810, 15753, 68290) already part of circuit 7
# joining in new circuit #236: (56025, 47852, 16876) (54567, 54158, 16096)
# joining in new circuit #237: (24610, 3171, 71281) (24630, 2860, 77796)
# joining pre-existing circuit #43: (80727, 75980, 99842)
# joining circuits 198 (n=7) and 201 (n=2) in 198
# new len of circuit 198 (n=9)
# joining pre-existing circuit #82: (75803, 85251, 47000)
# joining circuits 202 (n=2) and 124 (n=2) in 202
# new len of circuit 202 (n=4)
# skip. elements (62483, 8660, 44213) and (68263, 7170, 41519) already part of circuit 10
# joining pre-existing circuit #2: (41333, 74750, 38387)
# skip. elements (88516, 63642, 42624) and (92324, 66957, 38440) already part of circuit 22
# joining pre-existing circuit #9: (95019, 79410, 8181)
# joining pre-existing circuit #34: (4319, 12917, 20229)
# joining pre-existing circuit #57: (79296, 48670, 38594)
# joining circuits 156 (n=4) and 108 (n=2) in 156
# new len of circuit 156 (n=6)
# joining pre-existing circuit #192: (35184, 55774, 92625)
# joining pre-existing circuit #85: (52151, 35709, 11938)
# joining circuits 113 (n=5) and 77 (n=3) in 113
# new len of circuit 113 (n=8)
# joining in new circuit #238: (60137, 56411, 36201) (58468, 61269, 40329)
# joining pre-existing circuit #227: (43822, 62892, 89580)
# joining pre-existing circuit #5: (79255, 84067, 15019)
# skip. elements (6886, 7827, 1340) and (10466, 12639, 4121) already part of circuit 11
# joining in new circuit #239: (29171, 75432, 14507) (22741, 76439, 13327)
# joining circuits 106 (n=3) and 43 (n=6) in 106
# new len of circuit 106 (n=9)
# skip. elements (57063, 89270, 43680) and (53980, 88653, 37844) already part of circuit 60
# skip. elements (42553, 71880, 29425) and (37903, 76448, 28218) already part of circuit 2
# joining circuits 100 (n=3) and 126 (n=5) in 100
# new len of circuit 100 (n=8)
# joining in new circuit #240: (66287, 17768, 16402) (60225, 17652, 19096)
# joining in new circuit #241: (95085, 50988, 45896) (99271, 50001, 50949)
# joining pre-existing circuit #94: (14754, 173, 7567)
# skip. elements (44383, 60208, 56605) and (44545, 66073, 59746) already part of circuit 67
# skip. elements (33002, 21084, 76725) and (32570, 26366, 80757) already part of circuit 190
# joining in new circuit #242: (78309, 21724, 11348) (74311, 18925, 15880)
# joining pre-existing circuit #187: (31513, 90063, 51628)
# skip. elements (36175, 72813, 59266) and (30595, 76448, 59496) already part of circuit 209
# skip. elements (43033, 72228, 28791) and (37903, 76448, 28218) already part of circuit 2
# skip. elements (30243, 87825, 16291) and (24402, 85178, 18116) already part of circuit 37
# joining circuits 16 (n=3) and 206 (n=2) in 16
# new len of circuit 16 (n=5)
# skip. elements (52080, 22567, 11571) and (47365, 27230, 12297) already part of circuit 86
# skip. elements (81848, 22092, 18531) and (86689, 26472, 19922) already part of circuit 193
# joining pre-existing circuit #57: (72858, 40713, 52582)
# joining in new circuit #243: (72052, 91026, 95444) (78536, 89616, 94653)
# skip. elements (80821, 15501, 64608) and (85879, 16155, 68927) already part of circuit 25
# skip. elements (42081, 34984, 53573) and (48434, 33151, 52578) already part of circuit 65
# joining circuits 56 (n=6) and 103 (n=2) in 56
# new len of circuit 56 (n=8)
# joining pre-existing circuit #94: (27467, 7416, 2472)
# skip. elements (50725, 91581, 42922) and (53980, 88653, 37844) already part of circuit 60
# joining circuits 155 (n=3) and 175 (n=3) in 155
# new len of circuit 155 (n=6)
# joining pre-existing circuit #121: (21881, 77372, 25325)
# joining circuits 111 (n=8) and 236 (n=2) in 111
# new len of circuit 111 (n=10)
# joining pre-existing circuit #144: (76182, 17765, 39732)
# joining pre-existing circuit #218: (40564, 44438, 62224)
# joining pre-existing circuit #111: (49848, 49225, 20761)
# skip. elements (21881, 77372, 25325) and (22742, 73410, 19960) already part of circuit 121
# joining pre-existing circuit #134: (39743, 43515, 20006)
# joining in new circuit #244: (1783, 64512, 33127) (5878, 63680, 27847)
# joining pre-existing circuit #46: (29124, 98054, 80933)
# skip. elements (39415, 44712, 72242) and (35179, 49837, 73336) already part of circuit 156
# skip. elements (37355, 30445, 38934) and (34391, 36299, 40481) already part of circuit 109
# joining pre-existing circuit #215: (46805, 1901, 36070)
# skip. elements (59642, 49413, 22350) and (56025, 47852, 16876) already part of circuit 111
# joining circuits 63 (n=9) and 129 (n=5) in 63
# new len of circuit 63 (n=14)
# joining circuits 202 (n=4) and 158 (n=2) in 202
# new len of circuit 202 (n=6)
# joining pre-existing circuit #7: (63312, 12966, 65532)
# joining pre-existing circuit #7: (54046, 28627, 61767)
# joining pre-existing circuit #65: (33655, 17594, 44124)
# joining in new circuit #245: (51391, 87435, 62329) (52888, 84808, 68372)
# joining circuits 198 (n=9) and 172 (n=4) in 198
# new len of circuit 198 (n=13)
# skip. elements (47743, 71301, 77615) and (46415, 70487, 71036) already part of circuit 63
# joining pre-existing circuit #82: (70813, 94731, 54422)
# joining pre-existing circuit #50: (45654, 90427, 12)
# joining circuits 160 (n=2) and 99 (n=2) in 160
# new len of circuit 160 (n=4)
# joining circuits 60 (n=11) and 56 (n=8) in 60
# new len of circuit 60 (n=19)
# joining pre-existing circuit #21: (20783, 99905, 68899)
# skip. elements (56810, 26386, 67508) and (61871, 28559, 71466) already part of circuit 7
# joining in new circuit #246: (30579, 42802, 28334) (37242, 43031, 29584)
# skip. elements (54046, 28627, 61767) and (57972, 28578, 67304) already part of circuit 7
# skip. elements (57063, 89270, 43680) and (50725, 91581, 42922) already part of circuit 60
# joining pre-existing circuit #111: (59601, 50264, 11632)
# joining in new circuit #247: (71882, 59486, 30151) (70854, 64399, 25565)
# joining pre-existing circuit #37: (24175, 94365, 17226)
# joining circuits 180 (n=3) and 46 (n=4) in 180
# new len of circuit 180 (n=7)
# joining in new circuit #248: (28774, 66314, 91481) (33498, 63314, 95352)
# skip. elements (36361, 45237, 14358) and (39743, 43515, 20006) already part of circuit 134
# joining pre-existing circuit #17: (94280, 13380, 56635)
# skip. elements (63502, 18502, 70887) and (58945, 21508, 74957) already part of circuit 7
# joining circuits 187 (n=5) and 163 (n=2) in 187
# new len of circuit 187 (n=7)
# joining pre-existing circuit #144: (87264, 17247, 56358)
# joining pre-existing circuit #100: (36716, 60940, 36640)
# skip. elements (58280, 91324, 39288) and (54019, 93581, 44124) already part of circuit 60
# skip. elements (12525, 69643, 80364) and (9342, 64901, 76610) already part of circuit 52
# joining circuits 170 (n=5) and 80 (n=2) in 170
# new len of circuit 170 (n=7)
# joining pre-existing circuit #70: (15607, 36895, 64461)
# joining in new circuit #249: (60805, 60973, 74444) (67381, 61953, 72821)
# joining circuits 147 (n=5) and 57 (n=5) in 147
# new len of circuit 147 (n=10)
# joining in new circuit #250: (40896, 21010, 29644) (46263, 20857, 33909)
# skip. elements (15607, 36895, 64461) and (15342, 36065, 57658) already part of circuit 70
# joining circuits 33 (n=4) and 156 (n=6) in 33
# new len of circuit 33 (n=10)
# skip. elements (76182, 17765, 39732) and (82250, 20965, 39533) already part of circuit 144
# joining in new circuit #251: (91215, 37091, 51943) (92639, 42342, 56129)
# joining circuits 171 (n=5) and 198 (n=13) in 171
# new len of circuit 171 (n=18)
# joining pre-existing circuit #205: (60092, 1626, 51782)
# skip. elements (55372, 69770, 64512) and (51416, 70759, 70043) already part of circuit 63
# joining pre-existing circuit #87: (52179, 33777, 44904)
# joining pre-existing circuit #3: (15937, 23941, 41610)
# joining pre-existing circuit #149: (4618, 61444, 64768)
# joining circuits 231 (n=2) and 6 (n=2) in 231
# new len of circuit 231 (n=4)
# skip. elements (22772, 6437, 7418) and (27467, 7416, 2472) already part of circuit 94
# skip. elements (76450, 91507, 56306) and (80660, 94091, 51503) already part of circuit 82
# skip. elements (7037, 58510, 77807) and (9342, 64901, 76610) already part of circuit 52
# joining circuits 86 (n=6) and 85 (n=5) in 86
# new len of circuit 86 (n=11)
# joining in new circuit #252: (76003, 38588, 78811) (76452, 35401, 72705)
# joining in new circuit #253: (47577, 17566, 19570) (52795, 13522, 21611)
# joining in new circuit #254: (84054, 30047, 66818) (80139, 32660, 61759)
# joining circuits 150 (n=2) and 215 (n=3) in 150
# new len of circuit 150 (n=5)
# joining pre-existing circuit #41: (1344, 57489, 48806)
# joining pre-existing circuit #106: (83159, 79576, 90469)
# skip. elements (35179, 49837, 73336) and (33004, 44533, 77204) already part of circuit 33
# joining in new circuit #255: (69297, 22367, 92576) (70798, 29080, 93289)
# skip. elements (55411, 58938, 21882) and (48602, 57813, 21435) already part of circuit 111
# joining pre-existing circuit #104: (25507, 67116, 58240)
# joining pre-existing circuit #227: (48693, 75535, 85896)
# joining circuits 171 (n=18) and 160 (n=4) in 171
# new len of circuit 171 (n=22)
# joining circuits 92 (n=5) and 162 (n=3) in 92
# new len of circuit 92 (n=8)
# joining in new circuit #256: (94447, 25448, 83182) (94360, 32318, 84189)
# joining pre-existing circuit #60: (66804, 78536, 63979)
# joining pre-existing circuit #79: (84664, 82429, 41573)
# joining in new circuit #257: (33848, 66952, 20181) (32457, 65860, 26922)
# skip. elements (35993, 38181, 88666) and (30941, 41866, 91750) already part of circuit 59
# joining pre-existing circuit #73: (2515, 32110, 77553)
# joining circuits 70 (n=8) and 176 (n=2) in 70
# new len of circuit 70 (n=10)
# joining in new circuit #258: (76372, 96032, 82382) (82212, 92679, 84243)
# skip. elements (6372, 89533, 76248) and (6861, 93498, 70508) already part of circuit 89
# skip. elements (54019, 93581, 44124) and (57886, 97171, 39530) already part of circuit 60
# skip. elements (50453, 12604, 96216) and (54345, 7281, 98557) already part of circuit 159
# joining pre-existing circuit #212: (37397, 81921, 44780)
# joining in new circuit #259: (7058, 36948, 510) (8944, 30208, 307)
# ...
# skip. elements (81678, 82926, 23052) and (83952, 76135, 24942) already part of circuit 5
# skip. elements (17421, 89336, 24983) and (13627, 91894, 19150) already part of circuit 239
# skip. elements (2063, 92337, 39347) and (8416, 93605, 35726) already part of circuit 231
# skip. elements (56025, 47852, 16876) and (49848, 49225, 20761) already part of circuit 111
# joining pre-existing circuit #226: (50500, 14935, 85968)
# skip. elements (39992, 50610, 86416) and (46881, 53171, 87491) already part of circuit 192
# skip. elements (25818, 98014, 33452) and (20122, 97509, 28709) already part of circuit 229
# skip. elements (38764, 39852, 77546) and (33004, 44533, 77204) already part of circuit 27
# skip. elements (11183, 17766, 11176) and (15446, 22659, 7551) already part of circuit 16
# joining circuits 249 (n=2) and 63 (n=17) in 249
# new len of circuit 249 (n=19)
# skip. elements (62483, 8660, 44213) and (66381, 11590, 38596) already part of circuit 10
# skip. elements (82215, 83791, 22210) and (74862, 83524, 21083) already part of circuit 5
# skip. elements (2692, 14925, 40670) and (2684, 14952, 48118) already part of circuit 64
# joining circuits 94 (n=11) and 16 (n=5) in 94
# new len of circuit 94 (n=16)
# skip. elements (78438, 80566, 65309) and (85125, 77278, 64918) already part of circuit 155
# joining circuits 263 (n=2) and 182 (n=2) in 263
# new len of circuit 263 (n=4)
# joining pre-existing circuit #171: (89999, 71922, 90507)
# joining circuits 170 (n=20) and 65 (n=12) in 170
# new len of circuit 170 (n=32)
# skip. elements (23935, 72205, 34540) and (18807, 66871, 35623) already part of circuit 116
# joining pre-existing circuit #26: (5594, 1829, 54520)
# skip. elements (50070, 64177, 69373) and (46415, 70487, 71036) already part of circuit 249
# joining circuits 82 (n=6) and 168 (n=5) in 82
# new len of circuit 82 (n=11)
# skip. elements (6031, 13077, 81006) and (259, 12830, 85774) already part of circuit 92
# joining pre-existing circuit #4: (43999, 68551, 2048)
# joining circuits 73 (n=8) and 92 (n=8) in 73
# new len of circuit 73 (n=16)
# joining pre-existing circuit #41: (17675, 65440, 50089)
# skip. elements (79255, 84067, 15019) and (74862, 83524, 21083) already part of circuit 5
# skip. elements (3018, 85219, 38426) and (3334, 92501, 40239) already part of circuit 231
# joining circuits 142 (n=5) and 7 (n=12) in 142
# new len of circuit 142 (n=17)
# joining pre-existing circuit #187: (34598, 87921, 58135)
# joining circuits 166 (n=2) and 209 (n=5) in 166
# new len of circuit 166 (n=7)
# skip. elements (94822, 60653, 76242) and (89696, 65504, 73650) already part of circuit 171
# joining circuits 169 (n=3) and 194 (n=2) in 169
# new len of circuit 169 (n=5)
# skip. elements (55087, 65940, 62025) and (59770, 71782, 62761) already part of circuit 249
# joining pre-existing circuit #234: (59137, 25802, 56887)
# joining circuits 10 (n=5) and 141 (n=18) in 10
# new len of circuit 10 (n=23)
# joining circuits 218 (n=3) and 27 (n=12) in 218
# new len of circuit 218 (n=15)
# skip. elements (42484, 49979, 8155) and (40564, 48148, 15198) already part of circuit 134
# joining pre-existing circuit #192: (42018, 43696, 84229)
# joining pre-existing circuit #10: (61014, 4220, 38310)
# skip. elements (30741, 50346, 67279) and (34326, 45305, 71576) already part of circuit 218
# skip. elements (50900, 67651, 35035) and (48458, 62910, 40354) already part of circuit 170
# joining pre-existing circuit #239: (17601, 89321, 13286)
# skip. elements (3036, 26773, 73089) and (3821, 19731, 75670) already part of circuit 73
# joining pre-existing circuit #90: (48362, 45714, 88304)
# joining circuits 212 (n=13) and 265 (n=2) in 212
# new len of circuit 212 (n=15)
# skip. elements (1493, 9272, 45268) and (5496, 14006, 49580) already part of circuit 64
# skip. elements (55411, 58938, 21882) and (54567, 54158, 16096) already part of circuit 111
# joining pre-existing circuit #146: (86005, 23974, 12506)
# skip. elements (32817, 88581, 66462) and (26818, 93175, 66675) already part of circuit 187
# skip. elements (39361, 44695, 44520) and (40237, 51779, 47009) already part of circuit 170
# joining in new circuit #266: (24664, 67881, 149) (26646, 60596, 537)
# skip. elements (20435, 12775, 10812) and (22772, 6437, 7418) already part of circuit 94
# skip. elements (77085, 50590, 13612) and (78822, 49482, 6336) already part of circuit 113
# joining circuits 151 (n=6) and 232 (n=2) in 151
# new len of circuit 151 (n=8)
# joining circuits 207 (n=3) and 249 (n=19) in 207
# new len of circuit 207 (n=22)
# skip. elements (95439, 29383, 51917) and (97508, 31301, 58940) already part of circuit 152
# joining circuits 73 (n=16) and 222 (n=12) in 73
# new len of circuit 73 (n=28)
# skip. elements (25486, 79745, 52565) and (23680, 72684, 50502) already part of circuit 212
# joining circuits 246 (n=5) and 102 (n=2) in 246
# new len of circuit 246 (n=7)
# joining pre-existing circuit #260: (59427, 4828, 6538)
# skip. elements (83499, 75069, 28719) and (84739, 82331, 30534) already part of circuit 5
# skip. elements (26492, 92665, 59432) and (27921, 90943, 66682) already part of circuit 187
# skip. elements (19940, 69970, 16140) and (22741, 76439, 13327) already part of circuit 239
# joining circuits 251 (n=2) and 152 (n=7) in 251
# new len of circuit 251 (n=9)
# skip. elements (20809, 85884, 33364) and (25020, 83317, 27588) already part of circuit 239
# joining circuits 142 (n=17) and 234 (n=6) in 142
# new len of circuit 142 (n=23)
# joining circuits 212 (n=15) and 104 (n=3) in 212
# new len of circuit 212 (n=18)
# joining circuits 239 (n=13) and 37 (n=5) in 239
# new len of circuit 239 (n=18)
# joining pre-existing circuit #151: (4780, 49468, 30842)
# skip. elements (61257, 96072, 80693) and (65640, 89906, 81564) already part of circuit 188
# skip. elements (39165, 57781, 87780) and (45135, 53096, 88481) already part of circuit 192
# joining in new circuit #267: (12056, 62689, 32845) (12914, 58749, 26372)
# skip. elements (41695, 95037, 84822) and (35653, 98966, 82326) already part of circuit 180
# joining pre-existing circuit #250: (46013, 25866, 39662)
# joining pre-existing circuit #258: (82873, 86669, 79579)
# skip. elements (33655, 17594, 44124) and (32122, 22134, 50070) already part of circuit 170
# joining circuits 171 (n=23) and 155 (n=6) in 171
# new len of circuit 171 (n=29)
# skip. elements (63658, 39697, 70886) and (66636, 46552, 69301) already part of circuit 139
# joining circuits 90 (n=5) and 192 (n=13) in 90
# new len of circuit 90 (n=18)
# joining circuits 62 (n=2) and 161 (n=2) in 62
# new len of circuit 62 (n=4)
# joining pre-existing circuit #35: (2921, 92859, 29377)
# joining circuits 2 (n=5) and 257 (n=4) in 2
# new len of circuit 2 (n=9)
# skip. elements (64925, 17822, 70885) and (69754, 18853, 76737) already part of circuit 142
# skip. elements (64002, 81020, 92955) and (71376, 82006, 94810) already part of circuit 106
# joining in new circuit #268: (63579, 88844, 32342) (59075, 83272, 35079)
# joining pre-existing circuit #213: (86157, 37265, 19608)
# skip. elements (20483, 42652, 1866) and (19788, 35881, 5406) already part of circuit 19
# skip. elements (39165, 57781, 87780) and (39686, 57913, 80120) already part of circuit 90
# joining pre-existing circuit #73: (9837, 24451, 76395)
# skip. elements (61715, 60330, 67091) and (55303, 59740, 62898) already part of circuit 207
# joining circuits 105 (n=4) and 230 (n=2) in 105
# new len of circuit 105 (n=6)
# joining circuits 212 (n=18) and 170 (n=32) in 212
# new len of circuit 212 (n=50)
# skip. elements (60105, 95545, 75417) and (66649, 95496, 79453) already part of circuit 188
# skip. elements (4089, 48364, 11583) and (8289, 48158, 18027) already part of circuit 151
# skip. elements (25768, 76758, 64599) and (33258, 74994, 64527) already part of circuit 166
# joining in new circuit #269: (69568, 25868, 3453) (67410, 25952, 10842)
# skip. elements (63502, 18502, 70887) and (63312, 12966, 65532) already part of circuit 142
# skip. elements (83158, 32854, 75751) and (90335, 31355, 73367) already part of circuit 127
# skip. elements (31359, 63508, 57453) and (31883, 65301, 49971) already part of circuit 212
# skip. elements (84092, 93252, 14143) and (82046, 88064, 19470) already part of circuit 5
# skip. elements (10837, 20258, 31823) and (16315, 16447, 35696) already part of circuit 3
# skip. elements (28988, 69581, 51939) and (24114, 67884, 46203) already part of circuit 212
# skip. elements (90094, 67670, 3026) and (96272, 63700, 5398) already part of circuit 9
# skip. elements (19706, 36855, 27077) and (21861, 31642, 21805) already part of circuit 105
# skip. elements (17737, 15580, 7171) and (11838, 19540, 10195) already part of circuit 94
# skip. elements (88830, 72652, 76447) and (89696, 65504, 73650) already part of circuit 171
# skip. elements (38764, 39852, 77546) and (45142, 41794, 73641) already part of circuit 218
# skip. elements (64925, 17822, 70885) and (64283, 24896, 73941) already part of circuit 142
# skip. elements (37355, 30445, 38934) and (38877, 26946, 45667) already part of circuit 212
# joining pre-existing circuit #10: (81860, 13651, 23347)
# skip. elements (503, 24540, 74109) and (4387, 19502, 69689) already part of circuit 73
# skip. elements (80821, 15501, 64608) and (86644, 18413, 68809) already part of circuit 25
# joining pre-existing circuit #169: (26368, 18219, 24751)
# skip. elements (88830, 72652, 76447) and (88593, 76147, 69533) already part of circuit 171
# skip. elements (24988, 39612, 1029) and (19788, 35881, 5406) already part of circuit 19
# skip. elements (43999, 68551, 2048) and (37906, 65907, 6058) already part of circuit 4
# joining pre-existing circuit #239: (22543, 62726, 17136)
# joining in new circuit #270: (52117, 98019, 87098) (51119, 92236, 82008)
# joining in new circuit #271: (87804, 77096, 48027) (90215, 74221, 54832)
# skip. elements (6031, 13077, 81006) and (9568, 7227, 77305) already part of circuit 73
# skip. elements (59601, 50264, 11632) and (54567, 54158, 16096) already part of circuit 111
# skip. elements (65647, 85415, 67416) and (66804, 78536, 63979) already part of circuit 60
# skip. elements (58380, 29471, 46772) and (52179, 33777, 44904) already part of circuit 142
# skip. elements (25768, 76758, 64599) and (29430, 83027, 61804) already part of circuit 166
# skip. elements (79255, 84067, 15019) and (82215, 83791, 22210) already part of circuit 5
# skip. elements (83158, 32854, 75751) and (80325, 28120, 81243) already part of circuit 127
# joining pre-existing circuit #64: (12749, 14719, 46821)
# joining circuits 127 (n=5) and 252 (n=2) in 127
# new len of circuit 127 (n=7)
# joining pre-existing circuit #264: (30459, 3109, 44766)
# skip. elements (15378, 32488, 26055) and (21861, 31642, 21805) already part of circuit 105
# joining pre-existing circuit #45: (50293, 33964, 97680)
# skip. elements (20435, 12775, 10812) and (16779, 5900, 11279) already part of circuit 94
# skip. elements (66804, 78536, 63979) and (64073, 84972, 60519) already part of circuit 60
# skip. elements (94059, 62070, 80975) and (88452, 67409, 80013) already part of circuit 171
# skip. elements (48362, 45714, 88304) and (42018, 43696, 84229) already part of circuit 90
# skip. elements (26368, 18219, 24751) and (28967, 18083, 17390) already part of circuit 169
# skip. elements (15772, 17711, 25598) and (14656, 18849, 33244) already part of circuit 3
# joining pre-existing circuit #79: (89010, 86106, 46924)
# joining pre-existing circuit #159: (43038, 10680, 97753)
# skip. elements (9438, 62028, 73398) and (12150, 67733, 78002) already part of circuit 52
# skip. elements (6372, 89533, 76248) and (3861, 93315, 69864) already part of circuit 89
# joining pre-existing circuit #166: (37140, 81603, 62906)
# skip. elements (98743, 60846, 12266) and (96272, 63700, 5398) already part of circuit 9
# joining pre-existing circuit #212: (50768, 65547, 47364)
# skip. elements (58945, 21508, 74957) and (62764, 16129, 79192) already part of circuit 142
# skip. elements (23420, 14193, 6451) and (22772, 6437, 7418) already part of circuit 94
# joining circuits 140 (n=9) and 142 (n=23) in 140
# new len of circuit 140 (n=32)
# skip. elements (3821, 19731, 75670) and (896, 12924, 73091) already part of circuit 73
# joining circuits 12 (n=3) and 114 (n=5) in 12
# new len of circuit 12 (n=8)
# joining circuits 140 (n=32) and 208 (n=2) in 140
# new len of circuit 140 (n=34)
# skip. elements (86005, 23974, 12506) and (86689, 26472, 19922) already part of circuit 146
# skip. elements (9101, 61740, 47697) and (9564, 55512, 52463) already part of circuit 41
# skip. elements (81300, 7196, 87500) and (83460, 8483, 80043) already part of circuit 12
# joining circuits 171 (n=29) and 74 (n=2) in 171
# new len of circuit 171 (n=31)
# skip. elements (24111, 74954, 51360) and (19132, 71549, 56421) already part of circuit 212
# joining circuits 262 (n=2) and 2 (n=9) in 262
# new len of circuit 262 (n=11)
# skip. elements (44178, 31486, 49318) and (38877, 26946, 45667) already part of circuit 212
# joining pre-existing circuit #60: (64486, 83446, 41433)
# skip. elements (85140, 12764, 93612) and (78553, 16763, 95257) already part of circuit 204
# skip. elements (43949, 56387, 38313) and (40531, 51036, 42979) already part of circuit 212
# skip. elements (9765, 36804, 57491) and (17333, 38906, 58156) already part of circuit 73
# skip. elements (4283, 41791, 17248) and (9384, 36772, 13933) already part of circuit 151
# joining circuits 262 (n=11) and 111 (n=12) in 262
# new len of circuit 262 (n=23)
# skip. elements (62764, 16129, 79192) and (69754, 18853, 76737) already part of circuit 140
# joining pre-existing circuit #39: (73412, 82676, 78693)
# skip. elements (69431, 27247, 42783) and (68658, 24431, 35445) already part of circuit 51
# skip. elements (33655, 17594, 44124) and (26664, 18373, 47718) already part of circuit 212
# skip. elements (30785, 90334, 81150) and (29124, 98054, 80933) already part of circuit 180
# skip. elements (30426, 67953, 50954) and (24114, 67884, 46203) already part of circuit 212
# joining pre-existing circuit #258: (90387, 88576, 78048)
# joining circuits 23 (n=2) and 262 (n=23) in 23
# new len of circuit 23 (n=25)
# joining circuits 41 (n=7) and 212 (n=51) in 41
# new len of circuit 41 (n=58)
# skip. elements (88377, 1899, 79133) and (94776, 6539, 78851) already part of circuit 12
# joining circuits 268 (n=2) and 60 (n=22) in 268
# new len of circuit 268 (n=24)
# skip. elements (3036, 26773, 73089) and (9837, 24451, 76395) already part of circuit 73
# joining pre-existing circuit #18: (59377, 90569, 90881)
# skip. elements (37140, 81603, 62906) and (29430, 83027, 61804) already part of circuit 166
# skip. elements (38744, 31413, 46215) and (32423, 31757, 41456) already part of circuit 41
# joining circuits 61 (n=3) and 90 (n=18) in 61
# new len of circuit 61 (n=21)
# joining pre-existing circuit #220: (52927, 66687, 17820)
# skip. elements (30426, 67953, 50954) and (31359, 63508, 57453) already part of circuit 41
# skip. elements (34326, 45305, 71576) and (34841, 47498, 63972) already part of circuit 218
# joining circuits 247 (n=2) and 23 (n=25) in 247
# new len of circuit 247 (n=27)
# skip. elements (42553, 71880, 29425) and (40128, 69529, 22244) already part of circuit 247
# joining pre-existing circuit #264: (29162, 10607, 47022)
# skip. elements (1258, 10335, 99516) and (4432, 3412, 97257) already part of circuit 72
# skip. elements (45654, 90427, 12) and (44963, 94576, 6752) already part of circuit 50
# skip. elements (80772, 13542, 99369) and (76766, 11529, 92803) already part of circuit 204
# skip. elements (45635, 60095, 37602) and (41088, 66609, 37234) already part of circuit 41
# skip. elements (71389, 35612, 62781) and (73682, 33340, 55513) already part of circuit 147
# joining circuits 94 (n=16) and 34 (n=5) in 94
# new len of circuit 94 (n=21)
# joining pre-existing circuit #41: (37971, 86287, 35645)
# joining pre-existing circuit #166: (33428, 69840, 70592)
# skip. elements (27272, 23697, 53607) and (26664, 18373, 47718) already part of circuit 41
# joining pre-existing circuit #184: (4907, 43377, 38283)
# skip. elements (44048, 38624, 33976) and (48312, 43149, 29000) already part of circuit 246
# joining pre-existing circuit #86: (54992, 17840, 5860)
# joining pre-existing circuit #39: (69076, 81972, 85344)
# 62186

# %% [markdown]
# ## Part 2

# %%
def fully_connected(circuits):
    return len([c for c in circuits if c]) == 1 and len([c for c in circuits if c][0]) == len(pos)
    
def mk_circuits_full(pos, dist):
    circuits = []
    j2circ = {}

    for i in tqdm(range(len(dist))):    
        j1, j2 = tuple(pos[dist[i][0]]), tuple(pos[dist[i][1]])
        # print(j1, j2)
        if not j1 in j2circ and not j2 in j2circ:
            circuits.append([j1, j2])
            circidx = len(circuits)-1
            # print(f"joining in new circuit #{circidx}: {j1} {j2}")
            j2circ[j1] = circidx
            j2circ[j2] = circidx
        elif j1 in j2circ and not j2 in j2circ:
            circidx = j2circ[j1]
            # print(f"joining pre-existing circuit #{circidx}: {j2}")
            circuits[circidx].append(j2)
            j2circ[j2] = circidx
        elif not j1 in j2circ and j2 in j2circ:
            circidx = j2circ[j2]
            # print(f"joining pre-existing circuit #{circidx}: {j1}")
            circuits[circidx].append(j1)
            j2circ[j1] = circidx
        elif j1 in j2circ and j2 in j2circ:
            if j2circ[j1] == j2circ[j2]:
                # print(f"skip. elements {j1} and {j2} already part of circuit {j2circ[j1]}")
                continue
            # everybody joins circuit1
            # print(f"joining circuits {j2circ[j1]} (n={len(circuits[j2circ[j1]])}) and {j2circ[j2]} (n={len(circuits[j2circ[j2]])}) in {j2circ[j1]}")
            circid_j2 = j2circ[j2]
            circuits[j2circ[j1]].extend(circuits[circid_j2])
            for j in circuits[circid_j2]:
                j2circ[j] = j2circ[j1]
            circuits[circid_j2] = [] 
            # print(f"new len of circuit {j2circ[j1]} (n={len(circuits[j2circ[j1]])})")
        else:
            assert False
    
        if fully_connected(circuits):
            print(i, "full connect at", j1, j2)
            return j1, j2
            break
    return None, None

# %%
pos = data_to_3d(data)
dist = calc_distances(pos)
dist = sorted(dist, key = lambda x: x[2])
j1, j2 = mk_circuits_full(pos, dist)
if j1:
    print(j1[0] * j2[0])
# Out:
# 100%|█████████████████████████████████████████| 499500/499500 [00:00<00:00, 570465.28it/s]
#   1%|▌                                          | 6277/499500 [00:00<00:01, 281278.27it/s]
# 6277 full connect at (86005, 23974, 12506) (97906, 28543, 4213)
# 8420405530
